# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1:  READ DATA FILE & MAKE LIST OF EACH TYPE

# %%
path_slang = "datafile/abusive_slang.txt"
path_religious = "datafile/abusive_religious.txt"
path_personal_attack = "datafile/abusive_personal_attack.txt"
path_antifaminism = "datafile/abusive_antifaminism.txt"
path_political =  "datafile/abusive_political.txt"


def read_file(path):
    sent =[]
    sent.clear()
    with open(path, "r",encoding="utf-8") as f:
        for line in f:
            sent.append(line)
    return sent
slang_sent = read_file(path_slang)
religious_sent = read_file(path_religious)
personal_attack_sent = read_file(path_personal_attack)
political_sent = read_file(path_political)
antifaminism_sent = read_file(path_antifaminism)

# %%
print(religious_sent)
# Out:
# ['\ufeffশয়তান অনেক বড় আলেম ও আবেদ ছিল\n', 'মাসুদ ছোট আলেম ছোট শয়তান\n', 'তুই যে ইহুদিদের পয়দা করা কুকুর\n', 'তুই যে ইয়াহুদিদের দালাল তোর বেশ দেখেই বুঝা যাচ্ছে\n', 'তুই দাড়ি টুপি পড়িস কেন কাফের নাস্তিক\n', 'সংখ্যা লগু নাস্তিকদের নুতন সদস্য মাসুদএর পূর্বে রুশদী তসলিমা দাউদ হায়দর শাহরিয়ার এদের প্রভুদের হুকুমে কত কিছুই না করেছেন বা করতেছে ফলাফল শূন্য তুমি মাসুদ যে পেয়ে ফেল করেছ তা তোমার কথাতেই সুস্পষটছাগল আর কাকে বলেতোমার সস্তা কথা বা ভুমিকা এতই দূর্বল যে ঈমানদারদের বিভ্রান্ত করা শতভাগ অসম্ভবতোমার প্রভুদের কালেকশন পুরোপুরি ভুলঅতএব তোমার ব্যর্থ আস্ফালন প্রলাপই বটেসফল নাস্তিক হওয়া ও তোমার হলো নামাসুদ তোমার কপালে আছে শুধুই হায় হায়\n', 'তুই শয়তান\n', 'সারাজীবন ক্বওমী মাদ্রাসায় পড়ালেখা করে ফ্রি লোজিং খেয়ে ইসলামের বিরুদ্ধে বলতে খুব মজা\n', 'হুজুররা যে সর্ব প্রথম জাহান্নামে যাবে তার উদহারন হইলি তুই\n', 'তুই কাফের তুই নাস্তিক তুই সয়তান\n', 'তোর ভিতর এই শয়তানী ঢুকলো কখন থেকে\ufeff\n', 'তুই যদি ভিডিও না বানাস তোর নাস্তিক বস রা তো তর পাছায় লাত্তি দিয়া আবার দেশে পাঠাইবো\ufeff\n', 'টুপি আর পাঞ্জাবি পরছচ কেন কানা নাস্তিক\ufeff\n', 'আপনাদের ইসলাম আপনাদের নবী এগুলো কোন বেয়াদবীী\ufeff\n', 'তুই শয়তানের বাচ্চা কি সঠিক আর কি সঠিক না তা বলার তুই কে\n', 'এই তোকে নাস্তিক হওয়ার জন্য কে কত টাকা দিছে কুত্তার বাচ্চা\ufeff\n', 'তোকে শয়তানের আছর করেচে বানদর\ufeff\n', 'নাস্তিক অবস্থাই তোৰে আমাৰ সামনে পাইলেই হত্যা কৰমু\ufeff\n', 'তুই টুপি পানজাবী খোল আর দাড়ী রাখছচ কেন তোর বাবা তোর মায়ের সাথে মিলনের সময় দোয়া পড়ে নি তাই তোর এ অবস্হা\ufeff\n', 'ঐই কুততা তুই নাষতিক হয়েছিষ ঠিক আছে কিন্তু তুইএই লেবাছ কেনো\n', ' তুই তোর নাষতিকের লেবাস পরশালা কুততা\n', 'আরে আবালের আবাল ত
্রের মধ্যে সংগ্রহ করে সরস্বতীকে জন্ম দেন \n', 'পিতার যৌন দৃষ্টি থেকে অব্যাহতি পাওয়ার জন্য সরস্বতী চারটি দিকের জমিতে দৌড়াতে থাকেন \n', 'তিনি ব্রাহ্মের ইচ্ছাতে যৌন চাহিদা পূরণ করতে বাধ্য হন ব্রহ্মা \n', 'সরস্বতী স্বামী ও স্ত্রী হিসাবে বাস করতেন এবং  বছর ধরে তারা ব্যভিচারে জড়িত ছিলেন\n', 'মুসলমানরা অন্ধবিশ্বাসী\n', ' কুরআন যে মিথ্যা  আল্লাহ যে মিথ্যাবাদী ইসলাম ধর্ম মিথ্যা ধর্ম তাহা মানবে না\n', 'বিষ্ণু যৌনাবেদনময়ী অনুভূতি প্রকাশ করিয়াছিল\n', "ব্রহ্ম আনুসয়ায়কে কহিলেন  'আমার সাথে যৌন ক্রিয়ায় কর\n", 'ইসলাম জঙ্গি ও অমানবিক ধর্ম\ufeff\n', 'এইটাই মোল্লার ধর ...

# %% [markdown]
# # 2. REMOVE ALL BAD CHARECTER

# %%
import re
def digit_remover(text):
    text = re.sub(r'[\d]','',text)
    text = re.sub(r'[?\!\t\‛\’\(\)\.\।]+','',text)
    text = re.sub(r'[/\-\,]',' ',text)
    text = text.rstrip("\n\r")
    return text

# %%
print(digit_remover("হত্যাকাণ্ড/খারাপ,অদৃশ্য-কাল্পনিক,ধর্মের/ধার্মিকদের,0"))
# Out:
# হত্যাকাণ্ড খারাপ অদৃশ্য কাল্পনিক ধর্মের ধার্মিকদের

# %%
def remover(sent):
    for i in range(len(sent)):
        sent[i] = digit_remover(sent[i])
    return sent
slang_sent = remover(slang_sent)
religious_sent = remover(religious_sent)
personal_attack_sent = remover(personal_attack_sent)
political_sent = remover(political_sent)
antifaminism_sent = remover(antifaminism_sent)

# %%
print(religious_sent)
# Out:
# ['\ufeffশয়তান অনেক বড় আলেম ও আবেদ ছিল', 'মাসুদ ছোট আলেম ছোট শয়তান', 'তুই যে ইহুদিদের পয়দা করা কুকুর', 'তুই যে ইয়াহুদিদের দালাল তোর বেশ দেখেই বুঝা যাচ্ছে', 'তুই দাড়ি টুপি পড়িস কেন কাফের নাস্তিক', 'সংখ্যা লগু নাস্তিকদের নুতন সদস্য মাসুদএর পূর্বে রুশদী তসলিমা দাউদ হায়দর শাহরিয়ার এদের প্রভুদের হুকুমে কত কিছুই না করেছেন বা করতেছে ফলাফল শূন্য তুমি মাসুদ যে পেয়ে ফেল করেছ তা তোমার কথাতেই সুস্পষটছাগল আর কাকে বলেতোমার সস্তা কথা বা ভুমিকা এতই দূর্বল যে ঈমানদারদের বিভ্রান্ত করা শতভাগ অসম্ভবতোমার প্রভুদের কালেকশন পুরোপুরি ভুলঅতএব তোমার ব্যর্থ আস্ফালন প্রলাপই বটেসফল নাস্তিক হওয়া ও তোমার হলো নামাসুদ তোমার কপালে আছে শুধুই হায় হায়', 'তুই শয়তান', 'সারাজীবন ক্বওমী মাদ্রাসায় পড়ালেখা করে ফ্রি লোজিং খেয়ে ইসলামের বিরুদ্ধে বলতে খুব মজা', 'হুজুররা যে সর্ব প্রথম জাহান্নামে যাবে তার উদহারন হইলি তুই', 'তুই কাফের তুই নাস্তিক তুই সয়তান', 'তোর
'ইসলাম ধর্ম ফালতু ধর্ম\ufeff', 'নাড়ের বাচ্চাদের ধোনের চামড়া কাটিয়া কুরআন এর সাথে লাগিয়ে দিন ', ' হারামির ইসলামী মৌলবাদী জারজ দের পুড়িয়ে ছারখার করে দিন মাদারচুদের বাচ্চা রা সারা দুনিয়ায় হিংসা ছড়িয়েছে', 'খানকি মাগি জাকির নায়েক কি করছে\ufeff', 'ওই শালা মুফাস্সিল তুই এইসব হাদিস কই পাইছিস রে\ufeff', 'মোহাম্মদ কি ধর্ষক নাকি তার অনুসারীরা ধর্ষক\ufeff', 'হিন্দু দেব দেবীদের যৌনাচার:', 'হিন্দু দেবতা শিবা ও বিষ্ণুর সমকামীতার মাধমে তার জন্ম বিষ্ণু মহিনী', 'শিবা বিষ্ণুর সাথে যৌন ক্রিয়ায় লিপ্ত হ', 'বিষ্ণু সমকামীতার ফলে গর্ভবতী হয়ে পরে ও আয়াপ্পা দেবতার জন্ম দেয় \ufeff', 'ব্রহ্মা তার বীর্যকে একটি পাত্রের মধ্যে সংগ্রহ করে সরস্বতীকে জন্ম দেন ', 'পিতার যৌন দৃষ্টি থেকে অব্যাহতি পাওয়ার জন্য সরস্বতী চারটি দিকের জমিতে দৌড়াতে থাকেন ', 'তিনি ব্রাহ্মের ইচ্ছাতে যৌন চাহিদা পূরণ করতে বাধ্য হন ব্রহ্মা ', 'সরস্বতী স্বামী ও স্ত্রী হিসাবে বাস করতেন এবং  বছর ধরে তারা ব্যভিচারে জড়িত ছিলেন', 'মুসলমানরা অন্ধবিশ্বাসী', ' কুরআন যে মিথ্যা  আল্লাহ যে মিথ্যাবাদী ইসলাম ধর্ম মিথ্যা ধর্ম তাহা মানবে না', 'বিষ্ণু যৌনাবেদনময়ী অনুভূতি প্রকাশ করিয়াছিল', "ব্রহ্ম আনুসয়ায়কে কহিলেন  'আমার সাথে যৌন ক্রিয়ায় কর", 'ইসলাম জঙ্গি ও অমানবিক ধর্ম\ufeff', 'এইটাই মোল্লার ধর্ম ও কর্ম', 'ধর্মীয় মৌলবাদ কুকুরের পটির সমতুল্য সব চেয়ে বিপদজনক নেশা\ufeff', ' তোর নবীরে কুততা দিয়ে চো        ছি ...

# %% [markdown]
# # ADD COLUMN AND LABEL EACH TYPE OF DATA

# %%
slang_df = pd.DataFrame({'col':slang_sent})
slang_df['label'] = 1
religious_df = pd.DataFrame({'col':religious_sent})
religious_df['label'] = 2
personal_attack_df = pd.DataFrame({'col':personal_attack_sent})
personal_attack_df['label'] = 3
political_df = pd.DataFrame({'col':political_sent})
political_df['label'] = 4
antifaminism_df = pd.DataFrame({'col':antifaminism_sent})
antifaminism_df['label'] = 5

# %%
#attack_df.head()

# %% [markdown]
# # CONCATENATE EACH TYPE OF DATA AND SUFFLE THEM

# %%
frames = [slang_df, religious_df,personal_attack_df,political_df,antifaminism_df]
result = pd.concat(frames,ignore_index=True)
#suffle the data frame
result = result.sample(frac=1)

# %%
result.head(5)
# Out:
#                                                     col  label
# 1398              প্রমাণ করে দিলেন ভাই আপনি শিক্ষিত গরু      3
# 967                                   জানোয়ারের বাচ্চা﻿      3
# 837                                  ﻿তোদের কে বাশ দিব      3
# 982   সালা কুত্তার বাচ্চা মুফাসসিল জানুয়ারের বাচ্চার...      3
# 47                          আরে শালার মাগির জেন ফাশি হয়      1

# %% [markdown]
# # SPLIT DATA INTO TRAIN AND TEST SET

# %%
from sklearn.model_selection import train_test_split
X = result['col']
y = result['label']
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 1,test_size=.2)

# %%
#print(X_train[5])

# %%
result.shape
# Out:
# (2504, 2)

# %% [markdown]
# #  REPRESENTING TEXT AS NUMERICAL DATA

# %%
# import and instantiate CountVectorizer (with the default parameters)
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(tokenizer=lambda a: a.split(),ngram_range=(1, 3))

# %%
# learn the 'vocabulary' of the training data (occurs in-place)
X_train_dtm = vect.fit_transform(X_train)
X_test_dtm = vect.transform(X_test)

# %% [markdown]
# # APPLY MULTINOMIAL NAIVE BAYES ALGORITHM

# %%
# import and instantiate a Multinomial Naive Bayes model
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB(alpha=0.01)

# %%
# train the model using X_train_dtm (timing it with an IPython "magic command")
# %time nb.fit(X_train_dtm, y_train)
# Out:
# Wall time: 521 ms
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)

# %%
# make class predictions for X_test_dtm
y_pred_class = nb.predict(X_test_dtm)

# %%
# calculate accuracy of class predictions
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred_class)
# Out:
# 0.6167664670658682

# %%
input_sentence = ["ভাইজান কপালে সুধু অপু বুবলি মত ফ্লপ নায়িকা"]
input_sentence_dtm = vect.transform(input_sentence)

# %%
typo = nb.predict(input_sentence_dtm)
def get_result(result):
    if(typo==0):
        return ("slang sentence")
    
    elif(typo==1):
        return("religious_abusive_sentence")
    else:
        return("celebrity_abusive_sentence")

print(get_result(typo))
# Out:
# celebrity_abusive_sentence

# %% [markdown]
# # APPLY LINEAR SVC CLASSIFIER

# %%
from sklearn.svm import LinearSVC
svc = LinearSVC()
svc.fit(X_train_dtm, y_train)
y_pred_class_svc = svc.predict(X_test_dtm)

# %%
metrics.accuracy_score(y_test, y_pred_class_svc)
# Out:
# 0.6027944111776448

# %%
typo_svc = svc.predict(input_sentence_dtm)

def get_result(result):
    if(typo==0):
        return ("slang sentence")
    
    elif(typo==1):
        return("religious_abusive_sentence")
    else:
        return("celebrity_abusive_sentence")

print(get_result(typo_svc))
# Out:
# celebrity_abusive_sentence

# %% [markdown]
# # APPLY LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
logit = LogisticRegression()
logit.fit(X_train_dtm, y_train)
y_pred_class_logit = logit.predict(X_test_dtm)

# %%
metrics.accuracy_score(y_test, y_pred_class_logit)
# Out:
# 0.6167664670658682

# %%
typo_logit = logit.predict(input_sentence_dtm)
print(get_result(typo_logit))
# Out:
# celebrity_abusive_sentence

# %% [markdown]
# # APPLY RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
randomf = RandomForestClassifier(n_estimators=1000,max_depth=50)
randomf.fit(X_train_dtm, y_train)
y_pred_class_randomf = randomf.predict(X_test_dtm)

# %%
metrics.accuracy_score(y_test, y_pred_class_logit)
# Out:
# 0.6167664670658682

# %%
typo_randomf = logit.predict(input_sentence_dtm)
print(get_result(typo_randomf))
# Out:
# celebrity_abusive_sentence
